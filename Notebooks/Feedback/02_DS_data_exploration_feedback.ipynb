# %%
import pandas as pd

# %% [markdown]
# # Final demo dataset

# %%
df = pd.read_csv("../Data/Raw/df_final_demo.csv")
df.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
len(df)
# Out:
# 70609

# %%
df.tail()
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0

# %%
df.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.060900e+04    70595.000000      70595.000000  70594.000000
# mean   5.004992e+06       12.052950        150.659367     46.442240
# std    2.877278e+06        6.871819         82.089854     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519329e+06        6.000000         82.000000     32.500000
# 50%    5.016978e+06       11.000000        136.000000     47.000000
# 75%    7.483085e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70595.000000  7.059500e+04  70595.000000   70595.000000
# mean       2.255528  1.474452e+05      3.382478       5.566740
# std        0.534997  3.015087e+05      2.236580       2.353286
# min        1.000000  1.378942e+04      0.000000       1.000000
# ...

# %%
df["client_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['gendr'].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
# SABINA COMMENT: Why not do df.isna().sum()?
df['gendr'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['clnt_tenure_yr'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['clnt_tenure_mnth'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['clnt_age'].isnull().sum()
# Out:
# np.int64(15)

# %%
df['num_accts'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['bal'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['calls_6_mnth'].isnull().sum()
# Out:
# np.int64(14)

# %%
df['logons_6_mnth'].isnull().sum()
# Out:
# np.int64(14)

# %%
df[df.isnull().any(axis=1)]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 9583     4666211             8.0             106.0       NaN     F        2.0
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
# 18066    4876926             NaN               NaN       NaN   NaN        NaN
# 25961    5277910             NaN               NaN       NaN   NaN        NaN
# 28432    7616759             NaN               NaN       NaN   NaN        NaN
# 35323    8191345             NaN               NaN       NaN   NaN        NaN
# 43518    1227228             NaN               NaN       NaN   NaN        NaN
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# ...

# %%
df['num_accts'].min(), df['num_accts'].max()
# Out:
# (1.0, 8.0)

# %%
df['clnt_age'].min(), df['clnt_age'].max()
# Out:
# (13.5, 96.0)

# %%
df['calls_6_mnth'].min(), df['calls_6_mnth'].max()
# Out:
# (0.0, 7.0)

# %% [markdown]
# # Experiment clients dataset

# %%
df1 = pd.read_csv("../Data/Raw/df_final_experiment_clients.csv")
df1.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
len(df1)
# Out:
# 70609

# %%
df["client_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df1["Variation"].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df1['Variation'].isna().sum()
# Out:
# np.int64(20109)

# %% [markdown]
# # Webdata dataset - Part-1

# %% [markdown]
# SABINA COMMENT: Would've advised you to analyze both of these (pt1 and pt2) together, I don't see any reason why they should be separate.

# %%
df2 = pd.read_csv("../Data/Raw/df_final_web_data_pt_1.csv")
df2.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
len(df2)
# Out:
# 343141

# %%
df2["process_step"].unique()
# Out:
# array(['step_3', 'step_2', 'step_1', 'start', 'confirm'], dtype=object)

# %%
df2["process_step"].value_counts()
# Out:
# process_step
# start      108910
# step_1      73432
# step_2      61768
# step_3      53628
# confirm     45403
# Name: count, dtype: int64

# %%
df2["client_id"].value_counts()
# Out:
# client_id
# 2128341    84
# 9800867    66
# 9638063    64
# 2313292    61
# 5165430    60
#            ..
# 3939374     1
# 8477848     1
# 2606984     1
# 5141668     1
# 1266421     1
# Name: count, Length: 58391, dtype: int64

# %%
df2['client_id'].nunique()
# Out:
# 58391

# %%
steps_per_client = (
    df2.groupby('client_id')['process_step']
    .nunique()
    .sort_values(ascending=False)
)
steps_per_client.describe()
# Out:
# count    58391.000000
# mean         3.974585
# std          1.526914
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: process_step, dtype: float64

# %% [markdown]
# - Median is 5, so at least 50% of the clients completed the process
# - Most of the clients completed the process (75% is 5)
# SABINA COMMENT: Nope, 75% in the `describe()` method is a point (Q3), not an interval (min-Q3). The conclusion you had before was right and the reason that one is correct is because having 5 at the Q2 point means everything >Q2 (50% of the data) will be higher than 5.
# 75% (Q3) being equal to 5 means that everything >Q3 is >5 => 25% of the data is surely higher than 5. DM me if still unclear on this.
#
# - Mean is 3.97, denotes that some clients dropped off during the process

# %% [markdown]
# # Webdata dataset - Part-2

# %%
df3 = pd.read_csv("Data/Raw/df_final_web_data_pt_2.csv")
df3.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
len(df3)
# Out:
# 412264

# %%
df3["process_step"].unique()
# Out:
# array(['confirm', 'step_3', 'step_2', 'step_1', 'start'], dtype=object)

# %%
df3["process_step"].value_counts()
# Out:
# process_step
# start      135035
# step_1      89761
# step_2      71294
# step_3      58614
# confirm     57560
# Name: count, dtype: int64

# %%
df3["client_id"].value_counts()
# Out:
# client_id
# 5574879    104
# 2274658     90
# 5951379     80
# 1952790     80
# 3545814     72
#           ...
# 4220991      1
# 7506474      1
# 7414592      1
# 1156842      1
# 674799       1
# Name: count, Length: 67430, dtype: int64

# %%
df3['client_id'].nunique()
# Out:
# 67430

# %%
steps_per_client = (
    df3.groupby('client_id')['process_step']
    .nunique()
    .sort_values(ascending=False)
)
steps_per_client.describe()
# Out:
# count    67430.000000
# mean         4.025463
# std          1.494016
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: process_step, dtype: float64

# %% [markdown]
# - Median is 5, so at least 50% of the clients completed the process
# - Most of the clients completed the process (75% is 5)
# - Mean is 4.02, denotes that some clients dropped off during the later stages of the process
